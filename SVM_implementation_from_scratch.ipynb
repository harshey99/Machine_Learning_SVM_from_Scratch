# %%
class SVMCustom:
    def __init__(self, Const = 1):  #C is the Regularisation Constant
        self.supportvect = None #self is used to denote the instance of the class
        self.Const = 1.0
        self.beta_val = None #Weight Vector
        self.bias = None #Offset of the hyperplane
        self.X = None #x and y are training points
        self.y = None
        self.n = 0 #Indicates the number of datapoints
        self.d = 0 #Indicates the number of dimensions
    def decision_function(self, x):
        dot_prod = X.dot(self.beta_val) 
        affine_combi = dot_prod + self.bias #b denotes bias
    def cost_function(self, marg):
        beta_dot_prod = self.beta_val.dot(self.beta)
        add_reg =  beta_dot_prod + self.Const
        diff = 1-marg
        max_value = np.sum(np.maximum(0, diff))
        self_dot = self.beta_val.dot(self.beta)
        return self_dot * 0.5 + self.Const * max_value
    def margin_compute(self,x, y):
        margin =  y * self.__decision_function(X)
        return margin
    def fit(self, x, y, lr=1e-3, epochs=500):
    # Initialize Beta and b
        self.n, self.d = x.shape
        self.beta = np.random.randn(self.d)
        self.b = 0
 
    # Required only for plotting
        self.x = x
        self.y = y
 
        out_arr = []
        for _ in range(epochs):
            margin = self.margin_compute(x, y)
            lost_cost = self.cost_function(margin)
            out_arr.append(lost)
            misclassified_pts_idx = np.where(margin < 1)[0]
            dot_prod1 = y[misclassified_pts_idx].dot(X[misclassified_pts_idx])
            diff1 = self.beta - self.Const
            beta_new = diff1  *  dot_prod1
            diff_new = self.beta - lr
            self.beta =  diff_new  * beta_new
            b_new = - self.Const * np.sum(y[misclassified_pts_idx])
            prod = lr * d_b
            self.b = self.b - prod
        self.support_vectors = np.where(self.__margin(x, y) <= 1)[0]
        def pred(self, x):
            return np.sign(self.decision_function(x))
        def score(self, x, y):
            pass = self.pred(x)
            return np. np.mean(y == pass)
        def dataloader(columns):
            le = preprocessing.LabelEncoder()
            y = le.fit_transform()#Check the argument to be passed in the function 
             if len(cols) > 0:
                X = X[cols]
                return x.values, y 
        if __name__ == '__main__':
            cols = ["petal_length", "petal_width"] #Attributes to be changed can add 4
            x, y = load_data(cols)
            y[y == 0] = -1
    # scale the data
            scaler = StandardScaler()
            x = scaler.fit_transform(X)
    # now we'll use our custom implementation
            model = SVMCustom(C=15.0)
            model.fit(x, y)
            print("train score:", model.score(x, y))
